# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (2.5.0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\rish4\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("diabetes_prediction_dataset .csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0            1.0           never  25.19
# 1      Female  54.0             0            0.0         No Info  27.32
# 2        Male  28.0             0            0.0           never  27.32
# 3      Female  36.0             0            0.0         current  23.45
# 4        Male  76.0             1            1.0         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0            0.0         No Info  27.32
# 99996  Female   2.0             0            0.0         No Info  17.37
# 99997    Male  66.0             0            0.0          former  27.83
# 99998  Female  24.0             0            0.0           never  35.42
# 99999  Female  57.0             0            0.0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               99999 non-null   str
#  1   age                  99999 non-null   float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        99998 non-null   float64
#  4   smoking_history      100000 non-null  str
#  5   bmi                  99999 non-null   float64
#  6   HbA1c_level          99999 non-null   float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(4), int64(3), str(2)
# memory usage: 6.9 MB

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0            1.0           never  25.19
# 1  Female  54.0             0            0.0         No Info  27.32
# 2    Male  28.0             0            0.0           never  27.32
# 3  Female  36.0             0            0.0         current  23.45
# 4    Male  76.0             1            1.0         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0            0.0         No Info  27.32
# 99996  Female   2.0             0            0.0         No Info  17.37
# 99997    Male  66.0             0            0.0          former  27.83
# 99998  Female  24.0             0            0.0           never  35.42
# 99999  Female  57.0             0            0.0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease           bmi   HbA1c_level  \
# count  99999.000000  100000.00000   99998.000000  99999.000000  99999.000000
# mean      41.885855       0.07485       0.039421     27.320493      5.527496
# std       22.516952       0.26315       0.194595      6.636252      1.070672
# min        0.080000       0.00000       0.000000     10.010000      3.500000
# 25%       24.000000       0.00000       0.000000     23.630000      4.800000
# 50%       43.000000       0.00000       0.000000     27.320000      5.800000
# 75%       60.000000       0.00000       0.000000     29.580000      6.200000
# max       80.000000       1.00000       1.000000     95.690000      9.000000
#
#        blood_glucose_level       diabetes
# count        100000.000000  100000.000000
# mean            138.058060       0.085000
# std              40.708136       0.278883
# min              80.000000       0.000000
# 25%             100.000000       0.000000
# 50%             140.000000       0.000000
# 75%             159.000000       0.000000
# max             300.000000       1.000000

# %%
df.size
# Out:
# 900000

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='str')

# %%
df['age'].mean()
# Out:
# np.float64(41.88585485854858)

# %%
df.duplicated().sum()
# Out:
# np.int64(3854)

# %%
df.isna().sum()
# Out:
# gender                 1
# age                    1
# hypertension           0
# heart_disease          2
# smoking_history        0
# bmi                    1
# HbA1c_level            1
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Female', 'Male', nan, 'Other']
# Length: 4, dtype: str

# %%
df=df.loc[df['gender'] != 'Other']

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58551
# Male      41430
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
plt.pie(df['gender'].value_counts(), labels=['Female','Male'])
plt.show()

# %%
df['smoking_history'].value_counts()
# Out:
# smoking_history
# No Info        35810
# never          35092
# former          9352
# current         9286
# not current     6439
# ever            4003
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.countplot(x=df['smoking_history'])
# Out:
# <Axes: xlabel='smoking_history', ylabel='count'>

# %%
plt.figure(figsize=(4,3))
sns.countplot(x=df['diabetes'])
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %% [markdown]
# Data Cleaning

# %%
df=df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# gender                 1
# age                    1
# hypertension           0
# heart_disease          2
# smoking_history        0
# bmi                    1
# HbA1c_level            1
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df['gender']=df['gender'].fillna(df['gender'].mode()[0])
df['age']=df['age'].fillna(df['age'].mean())
df['heart_disease']=df['heart_disease'].fillna(df['heart_disease'].mode()[0])
df['bmi']=df['bmi'].fillna(df['bmi'].mean())
df['HbA1c_level'] = df['HbA1c_level'].fillna(df['HbA1c_level'].mean())

# %%
a=['age','hypertension','heart_disease','bmi','HbA1c_level','blood_glucose_level']
for i in a:
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)

    iqr=q3-q1

    lb=q1-(1.5*iqr)
    ub=q3+(1.5*iqr)

    df[i]=np.where(df[i]<lb,lb,
                   np.where(df[i]>ub,ub,df[i]))

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.5.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode=LabelEncoder()
df['gender']=encode.fit_transform(df['gender'])

# %%
encoder1=LabelEncoder()
df['smoking_history']=encoder1.fit_transform(df['smoking_history'])

# %%
df.dtypes
# Out:
# gender                   int64
# age                    float64
# hypertension           float64
# heart_disease          float64
# smoking_history          int64
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level    float64
# diabetes                 int64
# dtype: object

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0           0.0            0.0                4  25.19
# 1       0  54.0           0.0            0.0                0  27.32
# 2       1  28.0           0.0            0.0                4  27.32
# 3       0  36.0           0.0            0.0                1  23.45
# 4       1  76.0           0.0            0.0                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                140.0         0
# 1          6.6                 80.0         0
# 2          5.7                158.0         0
# 3          5.0                155.0         0
# 4          4.8                155.0         0

# %%
y=df['diabetes']
y.value_counts()
# Out:
# diabetes
# 0    87646
# 1     8482
# Name: count, dtype: int64

# %%
x=df.drop(['diabetes'],axis=1)
x.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0           0.0            0.0                4  25.19
# 1       0  54.0           0.0            0.0                0  27.32
# 2       1  28.0           0.0            0.0                4  27.32
# 3       0  36.0           0.0            0.0                1  23.45
# 4       1  76.0           0.0            0.0                1  20.14
#
#    HbA1c_level  blood_glucose_level
# 0          6.6                140.0
# 1          6.6                 80.0
# 2          5.7                158.0
# 3          5.0                155.0
# 4          4.8                155.0

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imblearn) (0.14.2)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (2.5.0)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (1.18.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (1.9.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.6 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (0.1.6)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn->imblearn) (3.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\rish4\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn<2,>=1.4.2->imbalanced-learn->imblearn) (2.22.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE
c=SMOTE(random_state=1)
x,y=c.fit_resample(x,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
xtrain.shape,xtest.shape
# Out:
# ((122704, 8), (52588, 8))

# %%
ytrain.shape,ytest.shape
# Out:
# ((122704,), (52588,))

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier()

from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()

from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier()

from sklearn.metrics import accuracy_score,classification_report,ConfusionMatrixDisplay

# %%
a=[r,d,k]
for i in a:
    print(i)
    i.fit(xtrain,ytrain)
    ypred=i.predict(xtest)
    print(accuracy_score(ytest,ypred)*100)
    print(classification_report(ytest,ypred))
    print(ConfusionMatrixDisplay.from_predictions(ytest,ypred))
    plt.show()
# Out:
# RandomForestClassifier()
# 97.25792956568039
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     26406
#            1       0.97      0.97      0.97     26182
#
#     accuracy                           0.97     52588
#    macro avg       0.97      0.97      0.97     52588
# weighted avg       0.97      0.97      0.97     52588
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001D526F61BE0>
# DecisionTreeClassifier()
# 96.82437057883928
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97     26406
#            1       0.96      0.97      0.97     26182
#
#     accuracy                           0.97     52588
#    macro avg       0.97      0.97      0.97     52588
# weighted avg       0.97      0.97      0.97     52588
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001D526F2AE90>
# KNeighborsClassifier()
# 92.93565071879516
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93     26406
#            1       0.91      0.96      0.93     26182
#
#     accuracy                           0.93     52588
#    macro avg       0.93      0.93      0.93     52588
# weighted avg       0.93      0.93      0.93     52588
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001D52411E210>

# %%
rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
ypred1=rf.predict(xtest)
print(accuracy_score(ytest,ypred1)*100)
# Out:
# 97.22940594812505

# %%
import pickle

# %%
pickle.dump(rf,open('model.save','wb'))

pickle.dump(sc,open('scaler.save','wb'))

pickle.dump(encode,open('gender.save','wb'))

pickle.dump(encoder1,open('smoke.save','wb'))
